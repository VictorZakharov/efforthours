# %% [markdown]
# # Normalization analysis
#
# This notebook documents the input contract, normalization rule, and interpretation of the result.

# %%
def normalize(value):
    return value.strip().lower()
